# %% [markdown]
# # House sale data
# Previously exported GraphLab data to csv and then load as a pandas object

# %%
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cross_validation import train_test_split as tts
from sklearn import linear_model

# %%
sales = pd.read_csv('home_data.csv')

# %%
sales_plot = sales.plot(x = 'sqft_living', y='price', kind='scatter')
plt.title('House prices')
plt.xlabel('Area in square feet')
plt.ylabel('Price')
plt.xlim([0,14000])
# Out:
# (0, 14000)

# %%
train, test = tts(sales, test_size=0.2, random_state=100)

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(sales['sqft_living'], sales['price'])
# Out:
# /home/henk/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-0c7a6802366a> in <module>()
# ----> 1 regr.fit(sales['sqft_living'], sales['price'])
#
# /home/henk/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     425         n_jobs_ = self.n_jobs
#     426         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 427                          y_numeric=True, multi_output=True)
#     428
# ...
